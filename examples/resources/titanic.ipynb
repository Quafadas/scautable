// %%
import $ivy.`io.github.quafadas::scautable:0.0.33-7-5f8997`
import $ivy.`io.github.quafadas::scautable-viz:0.0.33-7-5f8997`
import io.github.quafadas.table.*
import io.github.quafadas.scautable.ConsoleFormat.*
// Out:
// import $ivy.$
//
// import $ivy.$
//
// import io.github.quafadas.table.*
//
// import io.github.quafadas.scautable.ConsoleFormat.*

// %%
import viz.PlotTargets.almond

private val titanic = CSV.pwd("titanic.csv", TypeInferrer.FromAllRows)

val data = LazyList.from(
  titanic
    .dropColumn["PassengerId"]
    .addColumn["AgeIsDefined", Boolean](_.Age.isDefined)
)

val females = data.filter(_.Sex == "female")

Html(females.take(50).html)
// Out:
// <table id="scautable" class="display"><thead><tr><th>Survived</th><th>Pclass</th><th>Name</th><th>Sex</th><th>Age</th><th>SibSp</th><th>Parch</th><th>Ticket</th><th>Fare</th><th>Cabin</th><th>Embarked</th><th>AgeIsDefined</th></tr></thead><tbody><tr><td>true</td><td>1</td><td>Cumings, Mrs. John Bradley (Florence Briggs Thayer)</td><td>female</td><td>Some(38.0)</td><td>1</td><td>0</td><td>PC 17599</td><td>71.2833</td><td>Some(C85)</td><td>Some(C)</td><td>true</td></tr><tr><td>true</td><td>3</td><td>Heikkinen, Miss. Laina</td><td>female</td><td>Some(26.0)</td><td>0</td><td>0</td><td>STON/O2. 3101282</td><td>7.925</td><td>None</td><td>Some(S)</td><td>true</td></tr><tr><td>true</td><td>1</td><td>Futrelle, Mrs. Jacques Heath (Lily May Peel)</td><td>female</td><td>Some(35.0)</td><td>1</td><td>0</td><td>113803</td><td>53.1</td><td>Some(C123)</td><td>Some(S)</td><td>true</td></tr><tr><td>true</td><td>3</td><td>Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)</td><td>female</td><td>Some(27.0)</td><td>0</td><td>2</td><td>347742</td><td>11.1333</td><td>None</td><td>Some(S)</td><td>true</td></tr><tr><td>true</td><td>2</td><td>Nasser, Mrs. Nicholas (Adele Achem)</td><td>female</td><td>Some(14.0)</td><td>1</td><td>0</td><td>237736</td><td>30.0708</td><td>None</td><td>Some(C)</td><td>true</td></tr><tr><td>true</td><td>3</td><td>Sandstrom, Miss. Marguerite Rut</td><td>female</td><td>Some(4.0)</td><td>1</td><td>1</td><td>PP 9549</td><td>16.7</td><td>Some(G6)</td><td>Some(S)</td><td>true</td></tr><tr><td>true</td><td>1</td><td>Bonnell, Miss. Elizabeth</td><td>female</td><td>Some(58.0)</td><td>0</td><td>0</td><td>113783</td><td>26.55</td><td>Some(C103)</td><td>Some(S)</td><td>true</td></tr><tr><td>false</td><td>3</td><td>Vestrom, Miss. Hulda Amanda Adolfina</td><td>female</td><td>Some(14.0)</td><td>0</td><td>0</td><td>350406</td><td>7.8542</td><td>None</td><td>Some(S)</td><td>true</td></tr><tr><td>true</td><td>2</td><td>Hewlett, Mrs. (Mary D Kingcome) </td><td>female</td><td>Some(55.0)</td><td>0</td><td>0</td><td>248706</td><td>16.0</td><td>None</td><td>Some(S)</td><td>true</td></tr><tr><td>false</td><td>3</td><td>Vander Planke, Mrs. Julius (Emelia Maria Vandemoortele)</td><td>female</td><td>Some(31.0)</td><td>1</td><td>0</td><td>345763</td><td>18.0</td><td>None</td><td>Some(S)</td><td>true</td></tr><tr><td>true</td><td>3</td><td>Masselmani, Mrs. Fatima</td><td>female</td><td>None</td><td>0</td><td>0</td><td>2649</td><td>7.225</td><td>None</td><td>Some(C)</td><td>false</td></tr><tr><td>true</td><td>3</td><td>McGowan, Miss. Anna &quot;Annie&quot;</td><td>female</td><td>Some(15.0)</td><td>0</td><td>0</td><td>330923</td><td>8.0292</td><td>None</td><td>Some(Q)</td><td>true</td></tr><tr><td>false</td><td>3</td><td>Palsson, Miss. Torborg Danira</td><td>female</td><td>Some(8.0)</td><td>3</td><td>1</td><td>349909</td><td>21.075</td><td>None</td><td>Some(S)</td><td>true</td></tr><tr><td>true</td><td>3</td><td>Asplund, Mrs. Carl Oscar (Selma Augusta Emilia Johansson)</td><td>female</td><td>Some(38.0)</td><td>1</td><td>5</td><td>347077</td><td>31.3875</td><td>None</td><td>Some(S)</td><td>true</td></tr><tr><td>true</td><td>3</td><td>O'Dwyer, Miss. Ellen &quot;Nellie&quot;</td><td>female</td><td>None</td><td>0</td><td>0</td><td>330959</td><td>7.8792</td><td>None</td><td>Some(Q)</td><td>false</td></tr><tr><td>true</td><td>1</td><td>Spencer, Mrs. William Augustus (Marie Eugenie)</td><td>female</td><td>None</td><td>1</td><td>0</td><td>PC 17569</td><td>146.5208</td><td>Some(B78)</td><td>Some(C)</td><td>false</td></tr><tr><td>true</td><td>3</td><td>Glynn, Miss. Mary Agatha</td><td>female</td><td>None</td><td>0</td><td>0</td><td>335677</td><td>7.75</td><td>None</td><td>Some(Q)</td><td>false</td></tr><tr><td>false</td><td>3</td><td>Vander Planke, Miss. Augusta Maria</td><td>female</td><td>Some(18.0)</td><td>2</td><td>0</td><td>345764</td><td>18.0</td><td>None</td><td>Some(S)</td><td>true</td></tr><tr><td>true</td><td>3</td><td>Nicola-Yarred, Miss. Jamila</td><td>f ...
// import viz.PlotTargets.almond
//
//
// data: LazyList[NamedTuple[*:[scala.collection.immutable.LazyList[scala.NamedTuple.NamedTuple[scala.*:["Survived", scala.*:["Pclass", scala.*:["Name", scala.*:["Sex", scala.*:["Age", scala.*:["SibSp", scala.*:["Parch", scala.*:["Ticket", scala.*:["Fare", scala.*:["Cabin", scala.*:["Embarked", scala.*:["AgeIsDefined", scala.Tuple$package.EmptyTuple]]]]]]]]]]]], scala.*:[scala.Boolean, scala.*:[scala.Int, scala.*:[java.lang.String, scala.*:[java.lang.String, scala.*:[scala.Option[scala.Double], scala.*:[scala.Int, scala.*:[scala.Int, scala.*:[java.lang.String, scala.*:[scala.Double, scala.*:[scala.Option[java.lang.String], scala.*:[scala.Option[java.lang.String], scala.*:[scala.Boolean, scala.Tuple$package.EmptyTuple]]]]]]]]]]]]]], *:[scala.collection.immutable.LazyList[scala.NamedTuple.NamedTuple[scala.*:["Survived", scala.*:["Pclass", scala.*:["Name", scala.*:["Sex", scala.*:["Age", scala.*:["SibSp", scala.*:["Parch", scala.*:["Ticket", scala.*:["Fare", scala.*:["Cabin", scala.*:["Embarked", scala.*:["AgeIsDefined", scala.Tuple$package.EmptyTuple]]]]]]]]]]]], scala.*:[scala.Boolean, scala.*:[scala.Int, scala.*:[java.lang.String, scala.*:[java.lang.String, scala.*:[scala.Option[scala.Double], scala.*:[scala.Int, scala.*:[scala.Int, scala.*:[java.lang.String, scala.*:[scala.Double, scala.*:[scala.Option[java.lang.String], scala.*:[scala.Option[java.lang.String], scala.*:[scala.Boolean, scala.Tuple$package.EmptyTuple]]]]]]]]]]]]]], *:[scala.collection.immutable.LazyList[scala.NamedTuple.NamedTuple[scala.*:["Survived", scala.*:["Pclass", scala.*:["Name", scala.*:["Sex", scala.*:["Age", scala.*:["SibSp", scala.*:["Parch", scala.*:["Ticket", scala.*:["Fare", scala.*:["Cabin", scala.*:["Embarked", scala.*:["AgeIsDefined", scala.Tuple$package.EmptyTuple]]]]]]]]]]]], scala.*:[scala.Boolean, scala.*:[scala.Int, scala.*:[java.lang.String, scala.*:[java.lang.String, scala.*:[scala.Option[scala.Double], scala.*:[scala.Int, scala.*:[scala.Int, scala.*:[java.lang.String, scala.*:[scala.Double, scala.*:[scala.Option[java.lang.String], scala.*:[scala.Option[java.lang.String], scala.*:[scala.Boolean, scala.Tuple$package.EmptyTuple]]]]]]]]]]]]]], *:[scala.collection.immutable.LazyList[scala.NamedTuple.NamedTuple[scala.*:["Survived", scala.*:["Pclass", scala.*:["Name", scala.*:["Sex", scala.*:["Age", scala.*:["SibSp", scala.*:["Parch", scala.*:["Ticket", scala.*:["Fare", scala.*:["Cabin", scala.*:["Embarked", scala.*:["AgeIsDefined", scala.Tuple$package.EmptyTuple]]]]]]]]]]]], scala.*:[scala.Boolean, scala.*:[scala.Int, scala.*:[java.lang.String, scala.*:[java.lang.String, scala.*:[scala.Option[scala.Double], scala.*:[scala.Int, scala.*:[scala.Int, scala.*:[java.lang.String, scala.*:[scala.Double, scala.*:[scala.Option[java.lang.String], scala.*:[scala.Option[java.lang.String], scala.*:[scala.Boolean, scala.Tuple$package.EmptyTuple]]]]]]]]]]]]]], *:[scala.collection.immutable.LazyList[scala.NamedTuple.NamedTuple[scala.*:["Survived", scala.*:["Pclass", scala.*:["Name", scala.*:["Sex", scala.*:["Age", scala.*:["SibSp", scala.*:["Parch", scala.*:["Ticket", scala.*:["Fare", scala.*:["Cabi......
// females: LazyList[NamedTuple[*:[scala.collection.immutable.LazyList[scala.NamedTuple.NamedTuple[scala.*:["Survived", scala.*:["Pclass", scala.*:["Name", scala.*:["Sex", scala.*:["Age", scala.*:["SibSp", scala.*:["Parch", scala.*:["Ticket", scala.*:["Fare", scala.*:["Cabin", scala.*:["Embarked", scala.*:["AgeIsDefined", scala.Tuple$package.EmptyTuple]]]]]]]]]]]], scala.*:[scala.Boolean, scala.*:[scala.Int, scala.*:[java.lang.String, scala.*:[java.lang.String, scala.*:[scala.Option[scala.Double], scala.*:[scala.Int, scala.*:[scala.Int, scala.*:[java.lang.String, scala.*:[scala.Double, scala.*:[scala.Option[java.lang.String], scala.*:[scala.Option[java.lang.String], scala.*:[scala.Boolean, scala.Tuple$package.EmptyTuple]]]]]]]]]]]]]], *:[scala.collection.immutable.LazyList[scala.NamedTuple.NamedTuple[scala.*:["Survived", scala.*:["Pclass", scala.*:["Name", scala.*:["Sex", scala.*:["Age", scala.*:["SibSp", scala.*:["Parch", scala.*:["Ticket", scala.*:["Fare", scala.*:["Cabin", scala.*:["Embarked", scala.*:["AgeIsDefined", scala.Tuple$package.EmptyTuple]]]]]]]]]]]], scala.*:[scala.Boolean, scala.*:[scala.Int, scala.*:[java.lang.String, scala.*:[java.lang.String, scala.*:[scala.Option[scala.Double], scala.*:[scala.Int, scala.*:[scala.Int, scala.*:[java.lang.String, scala.*:[scala.Double, scala.*:[scala.Option[java.lang.String], scala.*:[scala.Option[java.lang.String], scala.*:[scala.Boolean, scala.Tuple$package.EmptyTuple]]]]]]]]]]]]]], *:[scala.collection.immutable.LazyList[scala.NamedTuple.NamedTuple[scala.*:["Survived", scala.*:["Pclass", scala.*:["Name", scala.*:["Sex", scala.*:["Age", scala.*:["SibSp", scala.*:["Parch", scala.*:["Ticket", scala.*:["Fare", scala.*:["Cabin", scala.*:["Embarked", scala.*:["AgeIsDefined", scala.Tuple$package.EmptyTuple]]]]]]]]]]]], scala.*:[scala.Boolean, scala.*:[scala.Int, scala.*:[java.lang.String, scala.*:[java.lang.String, scala.*:[scala.Option[scala.Double], scala.*:[scala.Int, scala.*:[scala.Int, scala.*:[java.lang.String, scala.*:[scala.Double, scala.*:[scala.Option[java.lang.String], scala.*:[scala.Option[java.lang.String], scala.*:[scala.Boolean, scala.Tuple$package.EmptyTuple]]]]]]]]]]]]]], *:[scala.collection.immutable.LazyList[scala.NamedTuple.NamedTuple[scala.*:["Survived", scala.*:["Pclass", scala.*:["Name", scala.*:["Sex", scala.*:["Age", scala.*:["SibSp", scala.*:["Parch", scala.*:["Ticket", scala.*:["Fare", scala.*:["Cabin", scala.*:["Embarked", scala.*:["AgeIsDefined", scala.Tuple$package.EmptyTuple]]]]]]]]]]]], scala.*:[scala.Boolean, scala.*:[scala.Int, scala.*:[java.lang.String, scala.*:[java.lang.String, scala.*:[scala.Option[scala.Double], scala.*:[scala.Int, scala.*:[scala.Int, scala.*:[java.lang.String, scala.*:[scala.Double, scala.*:[scala.Option[java.lang.String], scala.*:[scala.Option[java.lang.String], scala.*:[scala.Boolean, scala.Tuple$package.EmptyTuple]]]]]]]]]]]]]], *:[scala.collection.immutable.LazyList[scala.NamedTuple.NamedTuple[scala.*:["Survived", scala.*:["Pclass", scala.*:["Name", scala.*:["Sex", scala.*:["Age", scala.*:["SibSp", scala.*:["Parch", scala.*:["Ticket", scala.*:["Fare", scala.*:["C......

// %%
import io.github.quafadas.table.*
import scala.annotation.implicitNotFound
import scala.Tuple.Elem
import io.github.quafadas.scautable.ColumnTyped.IsColumn
import io.github.quafadas.scautable.ColumnTyped.IdxAtName
import scala.NamedTuple.NamedTuple
import viz.Plottable.plot


object Histogram:

  val histogramResource = "histogram.vg.json"

  extension [CC[X] <: Iterable[X], K <: Tuple, V <: Tuple](data: Iterable[NamedTuple[K, V]])

    inline def plotHistogram[S <: String](resourceSpec: Option[String] = None, maxBins: Option[Int])(using
        @implicitNotFound("Column ${S} not found")
        ev: IsColumn[S, K] =:= true,
        s: ValueOf[S],
        classTag: scala.reflect.ClassTag[Elem[V, IdxAtName[S, K]]]
    )(using ctx: viz.LowPriorityPlotTarget): Unit =
      import viz.vegaFlavour
      import viz.NamedTupleReadWriter.given_ReadWriter_T
      val oneCol = data.column[S]
      val specR = os.pwd / resourceSpec.fold(histogramResource)(_.trim)
      val colName: String = s.value


      def summonNumeric[T](cls: Class[?], colName: String): Option[Numeric[T]] = cls match {
        case c if c == classOf[Int] => Some(Numeric.IntIsIntegral.asInstanceOf[Numeric[T]])
        case c if c == classOf[Long] => Some(Numeric.LongIsIntegral.asInstanceOf[Numeric[T]])
        case c if c == classOf[Float] => Some(Numeric.FloatIsFractional.asInstanceOf[Numeric[T]])
        case c if c == classOf[Double] => Some(Numeric.DoubleIsFractional.asInstanceOf[Numeric[T]])
        case c if c == classOf[Short] => Some(Numeric.ShortIsIntegral.asInstanceOf[Numeric[T]])
        case c if c == classOf[Byte] => Some(Numeric.ByteIsIntegral.asInstanceOf[Numeric[T]])
        case c if c == classOf[BigInt] => Some(Numeric.BigIntIsIntegral.asInstanceOf[Numeric[T]])
        case c if c == classOf[BigDecimal] => Some(Numeric.BigDecimalIsFractional.asInstanceOf[Numeric[T]])
        case _ => None
      }

      // Get numeric instance for the column type
      val numeric: Option[Numeric[Elem[V, IdxAtName[S, K]]]] = summonNumeric[Elem[V, IdxAtName[S, K]]](classTag.runtimeClass, s.value)
      val titel = upickle.default.writeJs(
        (
          text = colName,
          fontSize = (
            expr = "width / 20"
          )
        )
      )

      numeric match
        case None =>
          specR.plot(
            List(
              spec => spec("data")("values") = oneCol.map:
                d => ujson.Obj("Col" -> d.toString()),
              spec =>
                spec("title") = titel
            )
          )

        case Some(numerical) =>
          val colName: String = s.value
          specR.plot(
            List(
              spec =>
                spec("data") = upickle.default.writeJs(
                  (values = oneCol.map: d =>
                    ujson.Obj(
                      colName -> numerical.toDouble(d)
                    ))
                ),
              spec => spec("encoding")("x") = ujson.Obj(
                "field" -> colName,
                "bin" -> maxBins.fold(ujson.Bool(true))(min => ujson.Obj("maxbins" -> min, "nice" -> true, "bin" -> true))
              ),
              spec => spec("description") = colName,
              spec => spec("title") = titel
            )
          )
    end plotHistogram

    inline def plotHistogram[S <: String](using
        @implicitNotFound("Column ${S} not found")
        ev: IsColumn[S, K] =:= true,
        s: ValueOf[S],

        classTag: scala.reflect.ClassTag[Elem[V, IdxAtName[S, K]]]
    )(using ctx: viz.LowPriorityPlotTarget): Unit = plotHistogram[S](None, None)

import Histogram.*
// Out:
// import io.github.quafadas.table.*
//
// import scala.annotation.implicitNotFound
//
// import scala.Tuple.Elem
//
// import io.github.quafadas.scautable.ColumnTyped.IsColumn
//
// import io.github.quafadas.scautable.ColumnTyped.IdxAtName
//
// import scala.NamedTuple.NamedTuple
//
// import viz.Plottable.plot
//
//
//
// defined object Histogram
// import Histogram.*

// %%
females.filter(_.AgeIsDefined).mapColumn["Age", Double](_.get).plotHistogram["Age"]
